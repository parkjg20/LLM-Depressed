# %%
import json
import pandas as pd

dataset = pd.read_json('./dataset.json') ## pd.read_json 이용
print(dataset[:10])
# Out:
#                                              profile  \
# 0  {'persona-id': 'Pro_05349', 'persona': {'perso...
# 1  {'persona-id': 'Pro_05349', 'persona': {'perso...
# 2  {'persona-id': 'Pro_05349', 'persona': {'perso...
# 3  {'persona-id': 'Pro_05349', 'persona': {'perso...
# 4  {'persona-id': 'Pro_05349', 'persona': {'perso...
# 5  {'persona-id': 'Pro_05349', 'persona': {'perso...
# 6  {'persona-id': 'Pro_05349', 'persona': {'perso...
# 7  {'persona-id': 'Pro_05397', 'persona': {'perso...
# 8  {'persona-id': 'Pro_05368', 'persona': {'perso...
# 9  {'persona-id': 'Pro_05397', 'persona': {'perso...
#
#                                                 talk
# 0  {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 1  {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 2  {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 3  {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 4  {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 5  {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 6  {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 7  {'id': {'profile-id': 'Pro_05397', 'talk-id': ...
# 8  {'id': {'profile-id': 'Pro_05368', 'talk-id': ...
# 9  {'id': {'profile-id': 'Pro_05397', 'talk-id': ...

# %%
# 코드 -> 텍스트 매핑 생성
map_age_band = {'A01': '청소년', 'A02': '청년', 'A03': '중년', 'A04': '노년'}
map_gender = {'G01': '남성', 'G02': '여성'}

# 상황 매핑
map_situation = {
    "S01": "가족관계",
    "S02": "학업 및 진로",
    "S03": "학교폭력/따돌림",
    "S04": "대인관계",
    "S05": "연애,결혼,출산",
    "S06": "진로,취업,직장",
    "S07": "대인관계(부부, 자녀)",
    "S08": "재정,은퇴,노후준비",
    "S09": "건강",
    "S10": "직장, 업무 스트레스",
    "S11": "건강,죽음",
    "S12": "대인관계(노년)",
    "S13": "재정"
}

# 질병 매핑
map_disease = {
    "D01": "만성질환 유",
    "D02": "만성질환 무"
}

# 감정 매핑
map_emotion = {
    "E10": "분노",
    "E11": "툴툴대는",
    "E12": "좌절한",
    "E13": "짜증내는",
    "E14": "방어적인",
    "E15": "악의적인",
    "E16": "안달하는",
    "E17": "구역질 나는",
    "E18": "노여워하는",
    "E19": "성가신",
    "E20": "슬픔",
    "E21": "실망한",
    "E22": "비통한",
    "E23": "후회되는",
    "E24": "우울한",
    "E25": "마비된",
    "E26": "염세적인",
    "E27": "눈물이 나는",
    "E28": "낙담한",
    "E29": "환멸을 느끼는",
    "E30": "불안",
    "E31": "두려운",
    "E32": "스트레스 받는",
    "E33": "취약한",
    "E34": "혼란스러운",
    "E35": "당혹스러운",
    "E36": "회의적인",
    "E37": "걱정스러운",
    "E38": "조심스러운",
    "E39": "초조한",
    "E40": "상처",
    "E41": "질투하는",
    "E42": "배신당한",
    "E43": "고립된",
    "E44": "충격 받은",
    "E45": "가난한, 불우한",
    "E46": "희생된",
    "E47": "억울한",
    "E48": "괴로워하는",
    "E49": "버려진",
    "E50": "당황",
    "E51": "고립된(당황한)",
    "E52": "남의 시선을 의식하는",
    "E53": "외로운",
    "E54": "열등감",
    "E55": "죄책감의",
    "E56": "부끄러운",
    "E57": "혐오스러운",
    "E58": "한심한",
    "E59": "혼란스러운(당황한)",
    "E60": "기쁨",
    "E61": "감사하는",
    "E62": "신뢰하는",
    "E63": "편안한",
    "E64": "만족스러운",
    "E65": "흥분",
    "E66": "느긋",
    "E67": "안도",
    "E68": "신이 난",
    "E69": "자신하는"
}

map_code = {
    'age_band': map_age_band,
    'gender': map_gender,
    'situation': map_situation,
    'disease': map_disease,
    'emotion': map_emotion
}

def decode(code_type, code):
     return map_code[code_type][code]

# %%
# 연령(profile.persona.human[0]) - [A01: 청소년, A02: 청년, A03: 중년, A04: 노년] 
# 성별(profile.persona.human[1]) - [G01: 남성, G02: 여성]

# 'human' 리스트에 'A01'이 포함된 레코드 필터링
filtered_dataset = dataset[dataset['profile'].apply(lambda x: 'A01' in x['persona']['human'])]

# 청소년 데이터 셋 크기
print(len(filtered_dataset))
# Out:
# 10581

# %%
# Data Flatten
flattened_profile = pd.json_normalize(filtered_dataset['profile'])
flattened_talk = pd.json_normalize(filtered_dataset['talk'])

combine = flattened_profile.join(flattened_talk)
print(combine)
# Out:
#       persona-id persona.persona-id persona.human persona.computer  \
# 0      Pro_00183        A01_G01_C01    [A01, G01]            [C01]
# 1      Pro_00183        A01_G01_C01    [A01, G01]            [C01]
# 2      Pro_00183        A01_G01_C01    [A01, G01]            [C01]
# 3      Pro_01869        A01_G02_C01    [A01, G02]            [C01]
# 4      Pro_01869        A01_G02_C01    [A01, G02]            [C01]
# ...          ...                ...           ...              ...
# 10576  Pro_01665        A01_G02_C01    [A01, G02]            [C01]
# 10577  Pro_00182        A01_G01_C01    [A01, G01]            [C01]
# 10578  Pro_01648        A01_G02_C01    [A01, G02]            [C01]
# 10579  Pro_01665        A01_G02_C01    [A01, G02]            [C01]
# 10580  Pro_01650        A01_G02_C01    [A01, G02]            [C01]
#
#       emotion.emotion-id emotion.type emotion.situation id.profile-id  \
# 0            S02_D02_E12          E12        [S02, D02]     Pro_00183
# 1            S02_D02_E12          E12        [S02, D02]     Pro_00183
# 2            S02_D02_E12          E12        [S02, D02]     Pro_00183
# 3            S03_D02_E18          E18        [S03, D02]     Pro_01869
# 4            S03_D02_E18          E18        [S03, D02]     Pro_01869
# ...                  ...          ...               ...           ...
# 10576        S01_D02_E54          E54        [S01, D02]     Pro_01665
# 10577        S02_D02_E11          E11        [S02, D02]     Pro_00182
# 10578        S01_D02_E37          E37        [S01, D02]     Pro_01648
# 10579        S01_D02_E54          E54        [S01, D02]     Pro_01665
# 10580        S01_D02_E39          E39        [S01, D02]     Pro_01650
#
#             id.talk-id                                       content.HS01  \
# 0      Pro_00183_00016             음악 실기 완전 망쳤어. 나는 왜 잘하는 게 하나도 없는지 모르겠다.
# 1      Pro_00183_00019    축제 때 전시할 그림을 나는 한 달 내내 준비했는데 친구는 겨우 이틀 만에 끝냈다네.
# 2      Pro_00183_00010              내가 어제 종일 피아노 쳤는데도 아무리 연습해도 실력이 늘지 않아.
# 3      Pro_01869_00022                             반 애들이 나만 따돌려서 너무 화가 나.
# 4      Pro_01869_00038                             친구들이 내 말을 무시하는 게 화가 나.
# ...                ...                                                ...
# 10576  Pro_01665_00022                       엄마가 내 학교생활까지 간섭하고 있어서 매번 싸워.
# 10577  Pro_00182_00014  부모님은 내 성적으로 매번 뭐라고 하셔. 학교에서는 공부 잘하는 편이라고 하는데 말이야.
# 10578  Pro_01648_00052                                   친구랑 싸웠어. 너무 속상해.
# 10579  Pro_01665_00011                   부모님이 내가 밖에 나가려고만 하면 간섭을 하셔. 속상해.
# 10580  Pro_01650_00014   부모님은 나에게 관심도 없어. 내가 무슨 말을 하든 다 잊어버리는 것 같아서 짜증 나.
#
#                                   content.SS01  \
# 0                  음악 실기 시험을 망쳐서 기분이 안 좋으시겠어요.
# 1          친구가 전시 그림을 이틀 만에 끝냈군요. 어떤 기분이 드셨나요?
# 2      피아노를 아무리 연습해도 실력이 늘지 않으시는군요. 마음이 어떠신가요?
# 3                          친구들이 따돌려서 화가 나시는군요.
# 4                     친구들이 말을 무시해서 정말 화가 나겠어요.
# ...                                        ...
# 10576           어머니가 개인적인 일에도 간섭하고 있어서 답답하시군요.
# 10577                 부모님과의 성적 문제 때문에 속상하시겠어요.
# 10578                          친구와 싸워서 속상하시군요.
# 10579                   속상하시군요. 기분이 좋지 않으시겠어요.
# 10580                      기분이 좋지 않아서 속상하시겠어요.
#
#                                             content.HS02  \
# 0                    보통 공부를 못하면 노래라도 잘 부르는데 나는 노래도 못 불러.
# 1                                     난 왜 이렇게 느린지 좌절스러워.
# 2                      속상하고 좌절스러워. 난 아무래도 피아노에 재능이 없나 봐.
# 3                                      도대체 나한테 왜 이러는 걸까?
# 4                                         왜 내 말을 무시한 거지?
# ...                                                  ...
# 10576  내가 지금보다 더 좋은 모습을 보여야 엄마가 간섭을 안 하실까? 다 부족한 내 잘못이야.
# 10577        내가 정말 열심히 하고 있는지 생각도 들고 나 자신을 탓하게 돼. 혼란스러워.
# 10578  친구가 나랑 놀면 우리 부모님이 하지 말라는 것 때문에 못 하는 게 너무 많다고 화...
# 10579          내가 너무 험하게 놀고 사고도 자주 쳐서 그런 거 같아. 기분이 안 좋아.
# 10580                       다들 자기 할 일 하느라 바빠. 난 신경도 안 써.
#
#                                             content.SS02  \
# 0      공부도 못하고 노래도 못 부르시는군요. 앞으로 음악 실기를 망치지 않으려면 어떻게 ...
# 1                  느려서 좌절을 느끼셨군요. 이 기분을 어떻게 낫게 할 수 있을까요?
# 2          피아노에 재능이 없는 것 같아 속상하시군요. 도움을 줄 수 있는 사람이 없을까요?
# 3             나에게 이러는 이유를 알고 싶으시군요. 이유를 알 수 있는 방법이 있을까요?
# 4           친구들이 말을 무시하는 이유를 알고 싶으시군요. 이유를 알아낼 방법이 있을까요?
# ...                                                  ...
# 10576                    지금 상황에서 벗어나기 위해 어떤 것을 할 수 있을까요?
# 10577                   어떻게 하는 것이 지금의 기분이 나아지게 할 수 있을까요?
# 10578                       어떻게 하면 지금의 상황에 변화를 줄 수 있을까요?
# 10579                   지금의 기분이 나아지게 할 수 있는 어떤 방법이 있을까요?
# 10580                      지금의 상황에서 어떻게 하는 것이 최선의 방법일까요?
#
#                                 content.HS03                    content.SS03
# 0                      노래를 연습하면 실기 성적이 좋아질까?              노래를 연습해 보려고 하시는군요.
# 1                      나는 작업을 꼼꼼하게 한다고 생각할래.       꼼꼼하게 작업하는 거라고 생각하려 하시는군요.
# 2                    피아노 선생님한테 도움을 청해 보고 싶어.         피아노 선생님께 도움을 청하려 하시는군요.
# 3       글쎄. 처음부터 날 따돌린 건 아니었는데 무슨 오해를 하고 있나?          친구들과 오해가 빨리 풀렸으면 좋겠어요.
# 4                      또 그러면 다음에는 직접 물어봐야겠어.         다음에는 이유를 직접 물어보려 하시는군요.
# ...                                      ...                             ...
# 10576        뭐 때문에 엄마가 매번 간섭하는지 얘기를 들어보고 싶어.  어머니와의 대화로 지금 상황을 잘 헤쳐 나가길 바라요.
# 10577              선생님께 성적에 관한 상담을 요청해보아야겠어.     선생님과의 대화에서 좋은 결과 얻으시면 좋겠어요.
# 10578  부모님과 진지한 대화도 해보고 친구와도 화해하려고 노력해보아야겠어.       원하시는 대로 일이 잘 해결되었으면 좋겠어요.
# 10579       신나는 음악을 들으면서 지금의 기분을 나아지게 하고 싶어.               즐거운 시간 되셨으면 좋겠어요.
# 10580      부모님과 밥 먹으면서 나한테 신경 좀 써달라고 얘기해야겠어.    부모님과 대화를 통해 좋은 결과 얻으시길 바랄게요.
#
# [10581 rows x 15 columns]

# %%
# 데이터 분석
df = pd.DataFrame(combine)
print('남성', len(df[df['persona.human'].apply(lambda x: x[1] == 'G01')]))
print('여성', len(df[df['persona.human'].apply(lambda x: x[1] == 'G02')]))
# Out:
# 남성 4460
# 여성 6121

# %%
# 데이터 확인
print(f"({df['emotion.type'][0]}, {decode('emotion', df['emotion.type'][0])})", df['content.HS01'][0])

df.info()
# Out:
# (E12, 좌절한) 음악 실기 완전 망쳤어. 나는 왜 잘하는 게 하나도 없는지 모르겠다.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10581 entries, 0 to 10580
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   persona-id          10581 non-null  object
#  1   persona.persona-id  10581 non-null  object
#  2   persona.human       10581 non-null  object
#  3   persona.computer    10581 non-null  object
#  4   emotion.emotion-id  10581 non-null  object
#  5   emotion.type        10581 non-null  object
#  6   emotion.situation   10581 non-null  object
#  7   id.profile-id       10581 non-null  object
#  8   id.talk-id          10581 non-null  object
#  9   content.HS01        10581 non-null  object
#  10  content.SS01        10581 non-null  object
#  11  content.HS02        10581 non-null  object
#  12  content.SS02        10581 non-null  object
#  13  content.HS03        10581 non-null  object
#  14  content.SS03        10581 non-null  object
# dtypes: object(15)
# memory usage: 1.2+ MB

# %%
# 감정 레이블 정수화
df['emotion_label'] = df['emotion.type'].astype('category').cat.codes
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10581 entries, 0 to 10580
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   persona-id          10581 non-null  object
#  1   persona.persona-id  10581 non-null  object
#  2   persona.human       10581 non-null  object
#  3   persona.computer    10581 non-null  object
#  4   emotion.emotion-id  10581 non-null  object
#  5   emotion.type        10581 non-null  object
#  6   emotion.situation   10581 non-null  object
#  7   id.profile-id       10581 non-null  object
#  8   id.talk-id          10581 non-null  object
#  9   content.HS01        10581 non-null  object
#  10  content.SS01        10581 non-null  object
#  11  content.HS02        10581 non-null  object
#  12  content.SS02        10581 non-null  object
#  13  content.HS03        10581 non-null  object
#  14  content.SS03        10581 non-null  object
#  15  emotion_label       10581 non-null  int8
# dtypes: int8(1), object(15)
# memory usage: 1.2+ MB
#   persona-id persona.persona-id persona.human persona.computer  \
# 0  Pro_00183        A01_G01_C01    [A01, G01]            [C01]
# 1  Pro_00183        A01_G01_C01    [A01, G01]            [C01]
# 2  Pro_00183        A01_G01_C01    [A01, G01]            [C01]
# 3  Pro_01869        A01_G02_C01    [A01, G02]            [C01]
# 4  Pro_01869        A01_G02_C01    [A01, G02]            [C01]
#
#   emotion.emotion-id emotion.type emotion.situation id.profile-id  \
# 0        S02_D02_E12          E12        [S02, D02]     Pro_00183
# 1        S02_D02_E12          E12        [S02, D02]     Pro_00183
# 2        S02_D02_E12          E12        [S02, D02]     Pro_00183
# 3        S03_D02_E18          E18        [S03, D02]     Pro_01869
# 4        S03_D02_E18          E18        [S03, D02]     Pro_01869
#
#         id.talk-id                                     content.HS01  \
# 0  Pro_00183_00016           음악 실기 완전 망쳤어. 나는 왜 잘하는 게 하나도 없는지 모르겠다.
# 1  Pro_00183_00019  축제 때 전시할 그림을 나는 한 달 내내 준비했는데 친구는 겨우 이틀 만에 끝냈다네.
# 2  Pro_00183_00010            내가 어제 종일 피아노 쳤는데도 아무리 연습해도 실력이 늘지 않아.
# 3  Pro_01869_00022                           반 애들이 나만 따돌려서 너무 화가 나.
# 4  Pro_01869_00038                           친구들이 내 말을 무시하는 게 화가 나.
#
#                               content.SS01  \
# 0              음악 실기 시험을 망쳐서 기분이 안 좋으시겠어요.
# 1      친구가 전시 그림을 이틀 만에 끝냈군요. 어떤 기분이 드셨나요?
# 2  피아노를 아무리 연습해도 실력이 늘지 않으시는군요. 마음이 어떠신가요?
# 3                      친구들이 따돌려서 화가 나시는군요.
# 4                 친구들이 말을 무시해서 정말 화가 나겠어요.
#
#                           content.HS02  \
# 0  보통 공부를 못하면 노래라도 잘 부르는데 나는 노래도 못 불러.
# 1                   난 왜 이렇게 느린지 좌절스러워.
# 2    속상하고 좌절스러워. 난 아무래도 피아노에 재능이 없나 봐.
# 3                    도대체 나한테 왜 이러는 걸까?
# 4                       왜 내 말을 무시한 거지?
#
#                                         content.SS02  \
# 0  공부도 못하고 노래도 못 부르시는군요. 앞으로 음악 실기를 망치지 않으려면 어떻게 ...
# 1              느려서 좌절을 느끼셨군요. 이 기분을 어떻게 낫게 할 수 있을까요?
# 2      피아노에 재능이 없는 것 같아 속상하시군요. 도움을 줄 수 있는 사람이 없을까요?
# 3         나에게 이러는 이유를 알고 싶으시군요. 이유를 알 수 있는 방법이 있을까요?
# 4       친구들이 말을 무시하는 이유를 알고 싶으시군요. 이유를 알아낼 방법이 있을까요?
#
#                            content.HS03               content.SS03  \
# 0                 노래를 연습하면 실기 성적이 좋아질까?         노래를 연습해 보려고 하시는군요.
# 1                 나는 작업을 꼼꼼하게 한다고 생각할래.  꼼꼼하게 작업하는 거라고 생각하려 하시는군요.
# 2               피아노 선생님한테 도움을 청해 보고 싶어.    피아노 선생님께 도움을 청하려 하시는군요.
# 3  글쎄. 처음부터 날 따돌린 건 아니었는데 무슨 오해를 하고 있나?     친구들과 오해가 빨리 풀렸으면 좋겠어요.
# 4                 또 그러면 다음에는 직접 물어봐야겠어.    다음에는 이유를 직접 물어보려 하시는군요.
#
#    emotion_label
# 0              2
# 1              2
# 2              2
# 3              8
# 4              8

# %%
### !pip install torch
# !which python
# Out:
# 'which'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import torch
from torch.utils.data import Dataset

class EmotionDataset(Dataset):
    def __init__(self, data, tokenizer, max_len):
        self.data = data
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        row = self.data.iloc[index]
        text = f"""{row['content.HS01']}
{row['content.HS02']}
{row['content.HS03']}"""
        label = row['emotion_label']

        encoding = self.tokenizer(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_tensors="pt"
        )

        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
# 학습 준비
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertForSequenceClassification
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# 데이터 분할
data_train, data_val = train_test_split(data, test_size=0.2, random_state=42)

# 2. KoBERT 모델 및 토크나이저 로드
MODEL_NAME = "skt/kobert-base-v1"
tokenizer = BertTokenizer.from_pretrained(MODEL_NAME)

MAX_LEN = 128
train_dataset = EmotionDataset(data_train, tokenizer, MAX_LEN)
val_dataset = EmotionDataset(data_val, tokenizer, MAX_LEN)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)

# 3. 모델 초기화
model = BertForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=data['emotion_label'].nunique())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# 4. 손실 함수 및 옵티마이저 설정
optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
criterion = torch.nn.CrossEntropyLoss()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 10
#       7 from sklearn.metrics import accuracy_score, classification_report
#       9 # 데이터 분할
# ---> 10 data_train, data_val = train_test_split(data, test_size=0.2, random_state=42)
#      12 # 2. KoBERT 모델 및 토크나이저 로드
#      13 MODEL_NAME = "skt/kobert-base-v1"
#
# NameError: name 'data' is not defined

# %%
filtered = df[df['profile.persona.human'] == 'A01']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 filtered = df[df['profile']['persona']['human'][0] == 'A01']
#
# File /usr/gatoai/python/venv/jupyter-3.6.8-py3.10/lib/python3.10/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /usr/gatoai/python/venv/jupyter-3.6.8-py3.10/lib/python3.10/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File /usr/gatoai/python/venv/jupyter-3.6.8-py3.10/lib/python3.10/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'persona'

# %%
# Out:
#                                                  profile  \
# 0      {'persona-id': 'Pro_05349', 'persona': {'perso...
# 1      {'persona-id': 'Pro_05349', 'persona': {'perso...
# 2      {'persona-id': 'Pro_05349', 'persona': {'perso...
# 3      {'persona-id': 'Pro_05349', 'persona': {'perso...
# 4      {'persona-id': 'Pro_05349', 'persona': {'perso...
# ...                                                  ...
# 51623  {'persona-id': 'Pro_10870', 'persona': {'perso...
# 51624  {'persona-id': 'Pro_12450', 'persona': {'perso...
# 51625  {'persona-id': 'Pro_12457', 'persona': {'perso...
# 51626  {'persona-id': 'Pro_11368', 'persona': {'perso...
# 51627  {'persona-id': 'Pro_11373', 'persona': {'perso...
#
#                                                     talk
# 0      {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 1      {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 2      {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 3      {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# 4      {'id': {'profile-id': 'Pro_05349', 'talk-id': ...
# ...                                                  ...
# 51623  {'id': {'profile-id': 'Pro_10870', 'talk-id': ...
# 51624  {'id': {'profile-id': 'Pro_12450', 'talk-id': ...
# 51625  {'id': {'profile-id': 'Pro_12457', 'talk-id': ...
# 51626  {'id': {'profile-id': 'Pro_11368', 'talk-id': ...
# 51627  {'id': {'profile-id': 'Pro_11373', 'talk-id': ...
#
# [51628 rows x 2 columns]
